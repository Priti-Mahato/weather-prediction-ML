# %%
import pandas as pd
weather = pd.read_csv("weather_data.csv",index_col="DATE")

# %%
weather
# Out:
#                 STATION                                               NAME  \
# DATE
# 01-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 02-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 03-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 04-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 05-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 01-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 02-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 03-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 04-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 05-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
#
# ...

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# AWND       0.679459
# FMTM       0.849131
# PGTM       0.861460
# PRCP       0.000805
# SNWD       0.316810
# TAVG       0.748784
# TMAX       0.001024
# TMIN       0.001097
# TOBS       0.999963
# TSUN       0.956210
# WDF2       0.680410
# WDF5       0.682861
# WESD       0.995500
# WSF2       0.680483
# WSF5       0.682568
# WT01       0.773258
# WT02       0.979001
# WT03       0.877739
# WT04       0.994513
# WT05       0.987232
# WT06       0.988037
# WT07       0.996927
# WT08       0.943186
# WT09       0.996012
# WT10       0.999963
# WT11       0.996159
# WT13       0.938723
# WT14       0.981087
# WT15       0.998390
# WT16       0.807134
# WT17       0.995610
# WT18       0.971319
# WT19       0.997293
# WT21       0.999012
# WT22       0.997549
# WV03       0.990598
# WV20       0.999561
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 01-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 02-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 03-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 04-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# 05-01-1950  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 01-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 02-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 03-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 04-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
# 05-11-2024  USW00013969  Netaji Subhash Chandra Bose International Airport
#
#             prcp  tmax  tmin
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['01-01-1950', '02-01-1950', '03-01-1950', '04-01-1950', '05-01-1950',
#        '06-01-1950', '07-01-1950', '08-01-1950', '09-01-1950', '10-01-1950',
#        ...
#        '27-10-2024', '28-10-2024', '29-10-2024', '30-10-2024', '31-10-2024',
#        '01-11-2024', '02-11-2024', '03-11-2024', '04-11-2024', '05-11-2024'],
#       dtype='object', name='DATE', length=27335)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index
# Out:
# <bound method Series.sort_index of 2008    366
# 2016    366
# 1972    366
# 1992    366
# 1980    366
#        ...
# 1951    365
# 1989    365
# 1962    364
# 1956    364
# 2024    310
# Name: DATE, Length: 75, dtype: int64>

# %%
weather["prcp"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1950-01-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-02-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-03-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-04-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-05-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 2024-01-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-02-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-03-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-04-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
#
#             prcp  tmax  tmin
# DATE
# ...

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1950-01-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-02-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-03-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-04-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-05-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 2024-01-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-02-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-03-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-04-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
#
#             prcp  tmax  tmin  target
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1950-01-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-02-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-03-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-04-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-05-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 2024-01-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-02-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-03-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-04-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
#
#             prcp  tmax  tmin  target
# DATE
# ...

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin'], dtype='object')

# %%
import numpy as np

def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
         # Clean data
        train = train.replace([np.inf, -np.inf], np.nan).dropna()
        test = test.replace([np.inf, -np.inf], np.nan).dropna()

        # Ensure no invalid values
        assert not train[predictors].isnull().values.any(), "Train predictors contain NaN!"
        assert not test[predictors].isnull().values.any(), "Test predictors contain NaN!"
        assert not train["target"].isnull().values.any(), "Train target contains NaN!"

        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        
        combined.columns = ["actual", "prediction"]
        
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1960-01-15    35.0   40.045618   5.045618
# 1960-01-16    32.0   40.106565   8.106565
# 1960-01-17    24.0   38.134532  14.134532
# 1960-01-18    24.0   33.853555   9.853555
# 1960-01-19    33.0   35.295760   2.295760
# ...            ...         ...        ...
# 2024-01-11    67.0   74.055233   7.055233
# 2024-02-11    67.0   67.456020   0.456020
# 2024-03-11    69.0   66.724149   2.275851
# 2024-04-11    69.0   68.017932   0.982068
# 2024-05-11    69.0   67.763599   1.236401
#
# [23667 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 6.0226359901953606

# %%
predictions["diff"].mean()
# Out:
# 6.425454097547178

# %%
def pct_diff(old, new):
    return (new-old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons = [3, 14]

for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1950-01-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-02-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-03-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-04-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-05-01  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 2024-01-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-02-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-03-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-04-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
#
# ...

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1950-01-15  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-16  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-17  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-18  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-19  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 2024-01-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-02-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-03-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-04-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
#
# ...

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1950-01-15  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-16  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-17  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-18  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1950-01-19  USW00013969  Netaji Subhash Chandra Bose International Airport
# ...                 ...                                                ...
# 2024-01-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-02-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-03-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-04-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 2024-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
#
# ...

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin', 'rolling_3_tmax', 'rolling_3_tmax_pct',
#        'rolling_3_tmin', 'rolling_3_tmin_pct', 'rolling_3_prcp',
#        'rolling_3_prcp_pct', 'rolling_14_tmax', 'rolling_14_tmax_pct',
#        'rolling_14_tmin', 'rolling_14_tmin_pct', 'rolling_14_prcp',
#        'rolling_14_prcp_pct', 'month_avg_tmax', 'day_avg_tmax',
#        'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp', 'day_avg_prcp'],
#       dtype='object')

# %%
predictons = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 6.4254540975471555

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2008-12-14    16.0   60.765008  44.765008
# 1989-03-03    25.0   68.801115  43.801115
# 1996-01-17    19.0   61.080707  42.080707
# 1963-02-20    24.0   65.761168  41.761168
# 1992-12-30    25.0   65.255394  40.255394
# ...            ...         ...        ...
# 2024-06-15    95.0   95.001185   0.001185
# 1979-10-11    42.0   42.001166   0.001166
# 1979-07-08    94.0   93.998878   0.001122
# 2019-07-22    87.0   86.999631   0.000369
# 1995-09-26    75.0   75.000267   0.000267
#
# [23685 rows x 3 columns]

# %%
weather.loc["1990-05-07":"1990-05-17"]
# Out:
#                 station                                               name  \
# DATE
# 1990-05-13  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-14  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-15  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-16  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-17  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-07  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-08  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-09  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-10  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-11  USW00013969  Netaji Subhash Chandra Bose International Airport
# 1990-05-12  USW00013969  Netaji Subhash Chandra Bose International Airport
#
# ...

# %%
(predictions["diff"].round().value_counts().sort_index().plot())
# Out:
# <AxesSubplot:>
